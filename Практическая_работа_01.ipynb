# %% [markdown]
# <a href="https://colab.research.google.com/github/David8596/Labs_1/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная работа 1. ПРИНЦИПЫ РАЗРАБОТКИ ПРОГРАММ

# %% [markdown]
# ## Задание

# %% [markdown]
# Тер-Маркарян Давид ИНБ-б-о-26-2

# %% [markdown]
# Необходимо вычислить значение выражения:
# $$Se=w111 + bt - x + y\cdot w$$
# Для каждой переменной необходимо вывести ее значение и тип.

# %% [markdown]
# ## Анализ выражения и определение переменных

# %% [markdown]
# Проанализируем выражение и определим переменные, которые потребуются для выполнения задания. Независимые переменные: $w111, bt, x, y, w$. Переменная, которая должна быть вычислена на основе независимых: $Se$.

# %%
w111=10
bt=30.67
x=5
y=5
w=50
print("w111 = ", w111, ", type(w111) = ", type(w111))
print("bt = ", bt, ", type(bt) = ", type(bt))
print("x = ", x, ", type(x) = ", type(x))
print("y = ", y, ", type(y) = ", type(y))
print("w = ", w, ", type(w) = ", type(w))
# Out:
# w111 =  10 , type(w111) =  <class 'int'>
# bt =  30.67 , type(bt) =  <class 'float'>
# x =  5 , type(x) =  <class 'int'>
# y =  5 , type(y) =  <class 'int'>
# w =  50 , type(w) =  <class 'int'>

# %% [markdown]
# ## Вычисление выражение, печать результатов

# %% [markdown]
# \Код для вычисления значения выражения $Se$:

# %%
Se = w111 + bt - x + y*w
print('Se=',Se)
print('Type of Se: ', type(Se))
# Out:
# Se= 285.67
# Type of Se:  <class 'float'>

# %% [markdown]
# Основные функции, используемые в данной практической работе: `print(), type(), abs()`

# %% [markdown]
# Ответы на контрольные вопросы:
#
#
# 1.
# 2.
