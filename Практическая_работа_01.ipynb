# %% [markdown]
# <a href="https://colab.research.google.com/github/David8596/Labs_1/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная работа 1. ПРИНЦИПЫ РАЗРАБОТКИ ПРОГРАММ

# %% [markdown]
# ## Задание

# %% [markdown]
# Тер-Маркарян Давид ИНБ-б-о-26-2

# %% [markdown]
# Необходимо вычислить значение выражения:
# $$Se=w111 + bt - x + y\cdot w$$
# Для каждой переменной необходимо вывести ее значение и тип.

# %% [markdown]
# ## Анализ выражения и определение переменных

# %% [markdown]
# Проанализируем выражение и определим переменные, которые потребуются для выполнения задания. Независимые переменные: $w111, bt, x, y, w$. Переменная, которая должна быть вычислена на основе независимых: $Se$.

# %%
w111=10
bt=30.67
x=5
y=5
w=50
print("w111 = ", w111, ", type(w111) = ", type(w111))
print("bt = ", bt, ", type(bt) = ", type(bt))
print("x = ", x, ", type(x) = ", type(x))
print("y = ", y, ", type(y) = ", type(y))
print("w = ", w, ", type(w) = ", type(w))
# Out:
# w111 =  10 , type(w111) =  <class 'int'>
# bt =  30.67 , type(bt) =  <class 'float'>
# x =  5 , type(x) =  <class 'int'>
# y =  5 , type(y) =  <class 'int'>
# w =  50 , type(w) =  <class 'int'>

# %% [markdown]
# ## Вычисление выражение, печать результатов

# %% [markdown]
# \Код для вычисления значения выражения $Se$:

# %%
Se = w111 + bt - x + y*w
print('Se=',Se)
print('Type of Se: ', type(Se))
# Out:
# Se= 285.67
# Type of Se:  <class 'float'>

# %% [markdown]
# Основные функции, используемые в данной практической работе: `print(), type(), abs()`

# %% [markdown]
# Ответы на контрольные вопросы:
#
#
# 1.   Компилируемый язык программирования читает весь код, преобразовывает его в двоичный, а потом уже выполняет готовый файл, который скомпилировался тогда, когда интерпритируемый выполняет код не преобразовывая ничего. Поэтому компилируемые языки пр. чаще всего строго типизированные.
# 2.   C++, C#, C, Java и другие
# 3.   Python, Js, Ts
# 4.   Чтобы объявить переменную, нужно написать её имя(первый символ не может быть цифрой, название переменной может содержать латинские буквы и цифры, нижние подчёркивания, но не специальные символы). Но если мы просто оставим название переменной, не проинициалищировав её(поставив знак "=" и её значение), то среда выполнения и сам питон будет ругаться "NameError: name 'a' is not defined". Поэтому для того, чтобы просто объявить переменную, можно написать её имя и указать её тип (name: str), и тогда можно не указывать её значение и среда не будет ругаться.
# 5.  Написать команду type(название переменной)
# 6.  print() используется для вывода в консоль какой-либо информации.
# 7.  функция abs(), ничего не надо импортировать.
# 8.  нельзя использовать int, create-var, 4perem, string, System.Double.
# 9.  Основные типы в python - int, str, float, dict, list, tuple.
# 10.  Утилита
# 11.  Прикладное ПО
# 12.  при кодировке utf-8 достаточно 8 бит.
# 13.  в двоичной системе счисления.
# 14.  задача схемы кодирования ASCII - представление и хранение в компьютере букв/символов в виде последовательности единиц и нулей.
# 15.  Unicode
# 16.  Цифровые данные - это данные, которые представленны в двоичном виде из нулей и единиц, а цифровые устройства - это устройства, которые хранят, передают, обрабатывают цифровые данные.
# 17.  Двоичный/бинарный код.
# 18.  Оперативная память.
# 19.  Цикл команд.
# 20.  Ассемблер - это, как по мне, самый низкоуровневый язык программирования, который использует последовательность слов, состваленных из определённых букв, позволяющих как можно ближе оращаться к процессору так, чтобы сам человек понимал код и то, как его написать для выполнения различных команд процессором.
